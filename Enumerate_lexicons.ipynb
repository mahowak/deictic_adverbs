# %%
from run_ib import RunIB
from enumerate_lexicons import get_random_lexicon
from ib import ib, mi, information_plane
import matplotlib.pyplot as plt
import numpy as np

# %%
x = RunIB(0.1,2.5,3)
lexicon_as_list = [3,2,0,1,1,0,3,2,0]
print(x.encode_lexicon(lexicon_as_list))
x.plot_lexicons(lexicon_as_list)
# Out:
# ((0.7207396028276354, 1.2347040987340303), -0.5671449083350582)

# %%
lexicon_as_list = [2,3,0,1,1,0,2,3,3]
print(x.encode_lexicon(lexicon_as_list))
x.plot_lexicons(lexicon_as_list)
# Out:
# ((0.7158333827156773, 1.2305490669881303), -0.559034389801063)

# %%
lexicon_as_list = [1,1,3,2,2,3,0,0,3]
print(x.encode_lexicon(lexicon_as_list))
x.plot_lexicons(lexicon_as_list)
# Out:
# ((0.6477186070473571, 1.1144764816295312), -0.5048200359888615)

# %%
lexicon_as_list = [1,3,3,2,3,3,0,3,3]
print(x.encode_lexicon(lexicon_as_list))
x.plot_lexicons(lexicon_as_list)
# Out:
# ((0.7102525618793285, 1.2348767882433096), -0.5407546164550117)
